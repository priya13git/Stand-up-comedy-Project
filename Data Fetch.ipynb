# %%
pip install google-api-python-client

# %%
pip install google-api-python-client -t ./lib

# %%
from googleapiclient.discovery import build
from openpyxl import Workbook
import pandas as pd
import seaborn as sns

api_key = 'AIzaSyCmnV7Vt-qUVmzaufEBbyONCzq2bAUelYs'
channel_ids = ['UCj22tfcQrWG7EMEKS0qLeEg', # Carryminati
              'UCqwUrj10mAEsqezcItqvwEw',  # Bhuvam bam
              "UCVmEbEQUGXHVm-O9pqa3JWg",  # Harsh Beniwal
              "UCt4atlExw8aj3Bm79nv1fig",  # Matlb Round2hell
              " UCy_xISfTbTwzmcMb6Xb25lw", # ab black id
              "UC0rE2qq81of4fojo-KhO5rg",  # Tanmay Bhatt
              "UCKnZHF24IV9PT0cdSdHoWug",  # Anubhav singh bassi
              "UCkS7Vxu4PjM99w0Is6idjcg",  # Zakir Khan 
              "UCDE7MoDdJwleaIAd3qFJF1A",  # Varun Grover
              "UCvLcuNVAb5sKRu7sHuFT0vQ",  # Vipul Goyal
              " UC4muYPMCSYigqIwRjVWkQ2Q", # Abhimanyu Upmanyu
              "UCAYum5hCyfkSH5T3vSD_kwQ",  # Akash Gupta
              "UCkS7Vxu4PjM99w0Is6idjcg",  # Zakir Khan
              "UC4aTcVTewbHtLeV8eK3enwA",  # Munawar faruki
              "UCGmhWgV9bmslB0Levatl6qA",  # harsh gujral
              "UCAov2BBv1ZJav0c_yHEciAw"]  #  samay raina

youtube = build('youtube', 'v3', developerKey=api_key)

## Function to get channel statistics
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = {
            'Channel_name': response['items'][i]['snippet']['title'],
            'Subscribers': response['items'][i]['statistics']['subscriberCount'],
            'Views': response['items'][i]['statistics']['viewCount'],
            'Total_videos': response['items'][i]['statistics']['videoCount'],
            'playlist_id' : response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    
    return all_data

get_channel_stats(youtube,channel_ids)
channel_statistics = get_channel_stats(youtube,channel_ids)

# %%
channel_statistics = get_channel_stats(youtube,channel_ids)

# %%
channel_statistics
# Out:
# [{'Channel_name': 'Aakash Gupta',
#   'Subscribers': '4050000',
#   'Views': '425594088',
#   'Total_videos': '44',
#   'playlist_id': 'UUAYum5hCyfkSH5T3vSD_kwQ'},
#  {'Channel_name': 'BB Ki Vines',
#   'Subscribers': '26400000',
#   'Views': '4915227020',
#   'Total_videos': '191',
#   'playlist_id': 'UUqwUrj10mAEsqezcItqvwEw'},
#  {'Channel_name': 'Round2hell',
#   'Subscribers': '32800000',
#   'Views': '3363666994',
#   'Total_videos': '68',
#   'playlist_id': 'UUt4atlExw8aj3Bm79nv1fig'},
#  {'Channel_name': 'Abhishek Upmanyu',
#   'Subscribers': '5120000',
#   'Views': '453939279',
#   'Total_videos': '20',
#   'playlist_id': 'UU4muYPMCSYigqIwRjVWkQ2Q'},
#  {'Channel_name': 'Anubhav Singh Bassi',
#   'Subscribers': '4940000',
#   'Views': '365630437',
#   'Total_videos': '8',
#   'playlist_id': 'UUKnZHF24IV9PT0cdSdHoWug'},
#  {'Channel_name': 'Harsh gujral',
#   'Subscribers': '2070000',
#   'Views': '192776043',
#   'Total_videos': '17',
# ...

# %%
channel_data=pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#            Channel_name Subscribers       Views Total_videos  \
# 0          Aakash Gupta     4050000   425594088           44
# 1           BB Ki Vines    26400000  4915227020          191
# 2            Round2hell    32800000  3363666994           68
# 3      Abhishek Upmanyu     5120000   453939279           20
# 4   Anubhav Singh Bassi     4940000   365630437            8
# 5          Harsh gujral     2070000   192776043           17
# 6           CarryMinati    41500000  3659116357          195
# 7              AB Black      103000     9319291           46
# 8           Vipul Goyal      766000    93672277           59
# 9           Tanmay Bhat     4690000  1451605486          994
# 10         Varun Grover     1020000    77205419           24
# 11        Harsh Beniwal    15800000  1908335406          168
# 12           Zakir Khan     7750000   757262180          187
# 13          Samay Raina     1310000   383314254          869
# ...

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
channel_data
# Out:
#            Channel_name  Subscribers       Views  Total_videos  \
# 0          Aakash Gupta      4050000   425594088            44
# 1           BB Ki Vines     26400000  4915227020           191
# 2            Round2hell     32800000  3363666994            68
# 3      Abhishek Upmanyu      5120000   453939279            20
# 4   Anubhav Singh Bassi      4940000   365630437             8
# 5          Harsh gujral      2070000   192776043            17
# 6           CarryMinati     41500000  3659116357           195
# 7              AB Black       103000     9319291            46
# 8           Vipul Goyal       766000    93672277            59
# 9           Tanmay Bhat      4690000  1451605486           994
# 10         Varun Grover      1020000    77205419            24
# 11        Harsh Beniwal     15800000  1908335406           168
# 12           Zakir Khan      7750000   757262180           187
# 13          Samay Raina      1310000   383314254           869
# ...

# %%
channel_data.to_csv('channel_data2.csv')

# %%
#Function to get video ids

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()

    video_ids = []

    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                     part = "ContentDetails",
                    playlistId = playlist_id,
                     maxResults = 50,
                     pageToken = next_page_token)
    
            response = request.execute()
            
            for i in range(len(response['items'])):
                    video_ids.append(response['items'][i]['contentDetails']['videoId'])
                    
            next_page_token = response.get('nextPageToken')    
    return (video_ids)
   # return video_ids

# %%
import numpy as n 
video_ids = []
for ind, channel in channel_data.iterrows():
    playlist_id = channel['playlist_id']
    print("playlist = ", playlist_id)
    video_id=get_video_ids(youtube, playlist_id)
#     print(video_id)
    video_ids += video_id
# Out:
# playlist =  UUAYum5hCyfkSH5T3vSD_kwQ
# playlist =  UUqwUrj10mAEsqezcItqvwEw
# playlist =  UUt4atlExw8aj3Bm79nv1fig
# playlist =  UU4muYPMCSYigqIwRjVWkQ2Q
# playlist =  UUKnZHF24IV9PT0cdSdHoWug
# playlist =  UUGmhWgV9bmslB0Levatl6qA
# playlist =  UUj22tfcQrWG7EMEKS0qLeEg
# playlist =  UUy_xISfTbTwzmcMb6Xb25lw
# playlist =  UUvLcuNVAb5sKRu7sHuFT0vQ
# playlist =  UU0rE2qq81of4fojo-KhO5rg
# playlist =  UUDE7MoDdJwleaIAd3qFJF1A
# playlist =  UUVmEbEQUGXHVm-O9pqa3JWg
# playlist =  UUkS7Vxu4PjM99w0Is6idjcg
# playlist =  UUAov2BBv1ZJav0c_yHEciAw
# playlist =  UU4aTcVTewbHtLeV8eK3enwA

# %%
video_ids
# Out:
# ['BTdF_neDzwk',
#  'bbBjFnXLeR8',
#  'inLh-UAWu_g',
#  'Q49PuDBQsX4',
#  'P02EQ5QgvO4',
#  'M8QOWNAC8jY',
#  'PBDxZkIJLNg',
#  'bwpXf5_SxD0',
#  'xbqGlB7a-zU',
#  'ETeG0FHwezU',
#  'KUzb3CWwOBk',
#  'T4XT5mdthRE',
#  'fUa5cFot6vU',
#  '_kwGDmQ9HFc',
#  'QH0vTw3eV2k',
#  'pjSxOnCkHIA',
#  'pl0zsJ5Y4Vw',
#  'he9pyFr4wKw',
#  'Y2Oj9gllHno',
#  'rVaiKp6VDCQ',
#  'FZ77MTzLdE0',
#  'AI0wH097nkM',
#  '6d2wzfx4sRs',
#  'S-0ZoAfC-4Q',
#  '2N7oed7skTk',
#  'hoowY2FSJis',
#  'hedTMU0rSS0',
#  '_WR-wfbM89Q',
#  'KBZfnt80s54',
#  '8bPWXYM2ysU',
#  '7JHa8aMhHPY',
#  'nN2XSigfJd0',
#  'e3nj1z7w-tg',
#  '28-7Jki3PEM',
#  'iBt2sPfeGRs',
#  'FC1YPRr8p2M',
#  'PTIaBLtp4R8',
#  '4vZ8RkBMUUE',
#  'Xc5n49aEhwc',
#  'GE8vyfKyZfQ',
#  'jydRGuVmCV8',
#  'eiJuocChiyA',
#  'Ou1S_NS_Zt4',
#  'QMhnal-vq4o',
#  'PJ3ZQk_lr9E',
#  'UrIaQbIK2E4',
#  'Nwh6CQ50h0g',
#  'HbTON0nb4DU',
#  'zm6xa3ggt5A',
#  'xNTW2KfErTM',
#  'cVPI4ppiDSA',
#  'xna_PkWzPVE',
#  'PgKxqbXO198',
#  'WEExPj6CMss',
#  'l8zlKap1JEo',
# ...

# %%
#Function to get video details

# %%
## fetching the original data

def get_videos_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        video_ids_slice = video_ids[i:i+50]
        request = youtube.videos().list(
            part='snippet,statistics,contentDetails',
            id=','.join(video_ids_slice)
        )
        response = request.execute()
        
        for video in response.get('items', []):
            
            print(video['snippet'])
            print('\n\n\n')
            return []
            video_stats = {
                'Channel_ID':video['snippet']['channelId'],
                'Channel_name': video['snippet']['channelTitle'],
                'Video_Title': video['snippet']['title'],
                'Published_Date': video['snippet']['publishedAt'],
                'Views': video['statistics']['viewCount'],
                'Likes': video['statistics'].get('likeCount', 0),
                'Comments': video['statistics'].get('commentCount', 0),
                'Video Duration': video['contentDetails'].get('duration'),
                'Instagram_ID':video['snippet']['Instagram'],
                'LinkedIn_ID':video['snippet']['LinkedIn']
            }
            all_video_stats.append(video_stats)
    
    return all_video_stats
video_details1 = get_videos_details(youtube,video_ids)
# Out:
# {'publishedAt': '2024-03-18T14:30:07Z', 'channelId': 'UC0rE2qq81of4fojo-KhO5rg', 'title': 'ELVISH MAXTERN TRUTH EXPOSED', 'description': 'Register for Renaissance Hackathon here: https://www.colosseum.org/renaissance\nNeed an idea for your web3 start up? Go to https://build.superteam.fun/ and find inspiration from 200+ ideas and other dev resources for the hackathon \nAaaaand if you want to meet other participants, meet them at a Superteam India Buildstation IRl - follow https://twitter.com/SuperteamDAO for more details \n\nYou can also follow Superteam India on our discord: Superteam India discord (https://discord.com/invite/Mq3ReaekgG)\n\n\nFOLLOW:\n\n• Jasmeet Bhatia - https://www.instagram.com/duhjizzy/?hl=en\n• Rohan Joshi - https://www.instagram.com/mojorojo/\n• Aaditya Kulshreshth - https://www.instagram.com/kullubaaazi/\n• Piyush Sharma - https://www.instagram.com/misterpiyush/\n\nCHECK OUT MY OTHER CHANNELS\n• Honestly by Tanmay Bhat: https://www.youtube.com/@HonestlybyTanma
# ...

# %%
# snippet - Instagram, LinkedIn, twitter id
#

# %%
def get_videos_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        video_ids_slice = video_ids[i:i+50]
        request = youtube.videos().list(
            part='snippet,statistics,contentDetails',
            id=','.join(video_ids_slice)
        )
        response = request.execute()
        
        for video in response.get('items', []):
           
            video_stats = {
                'Channel_ID':video['snippet']['channelId'],
                'Channel_name': video['snippet']['channelTitle'],
                'Video_Title': video['snippet']['title'],
                'Published_Date': video['snippet']['publishedAt'],
                'Views': video['statistics']['viewCount'],
                'Likes': video['statistics'].get('likeCount', 0),
                'Comments': video['statistics'].get('commentCount', 0),
                'Video Duration': video['contentDetails'].get('duration'),
                
            }
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details1 = get_videos_details(youtube,video_ids)

# %%
video_data = pd.DataFrame(video_details1)

# %%
video_data
# Out:
#                     Channel_ID     Channel_name  \
# 0     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 1     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 2     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 3     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 4     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# ...                        ...              ...
# 2282  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2283  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2284  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2285  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2286  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
#
#                                             Video_Title        Published_Date  \
# 0                                      Vaccine cocktail  2024-02-14T14:28:54Z
# 1     Australia NZ Tour Feb 2024 Announcement #aakas...  2024-02-13T12:40:18Z
# 2            Narcotics | Stand-up Comedy | Aakash Gupta  2024-01-07T05:33:25Z
# ...

# %%
#video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                     Channel_ID     Channel_name  \
# 0     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 1     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 2     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 3     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# 4     UCAYum5hCyfkSH5T3vSD_kwQ     Aakash Gupta
# ...                        ...              ...
# 2282  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2283  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2284  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2285  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
# 2286  UC4aTcVTewbHtLeV8eK3enwA  Munawar Faruqui
#
#                                             Video_Title        Published_Date  \
# 0                                      Vaccine cocktail  2024-02-14T14:28:54Z
# 1     Australia NZ Tour Feb 2024 Announcement #aakas...  2024-02-13T12:40:18Z
# 2            Narcotics | Stand-up Comedy | Aakash Gupta  2024-01-07T05:33:25Z
# ...
